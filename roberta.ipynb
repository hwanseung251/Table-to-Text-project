# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# Collecting googletrans==4.0.0-rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==4.0.0-rc1)
#   Downloading httpx-0.13.3-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.8.30)
# Collecting hstspreload (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hstspreload-2024.11.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting idna==2.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading httpcore-0.9.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h11-0.9.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h2-3.2.0-py2.py3-none-any.whl.metadata (32 kB)
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl.metadata (7.2 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 4.9 MB/s eta 0:00:00
# Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 8.8 MB/s eta 0:00:00
# Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.6 MB/s eta 0:00:00
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.9 MB/s eta 0:00:00
# Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 5.4 MB/s eta 0:00:00
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading hstspreload-2024.11.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 60.5 MB/s eta 0:00:00
# Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 5.6 MB/s eta 0:00:00
# Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17397 sha256=6089de9c259c2c7e055c0948a90728897c6a97acaf8b084c6ddd253e4755a5b1
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.6
#     Uninstalling httpcore-1.0.6:
#       Successfully uninstalled httpcore-1.0.6
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.2
#     Uninstalling httpx-0.27.2:
#       Successfully uninstalled httpx-0.27.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langsmith 0.1.137 requires httpx<1,>=0.23.0, but you have httpx 0.13.3 which is incompatible.
# openai 1.52.2 requires httpx<1,>=0.23.0, but you have httpx 0.13.3 which is incompatible.
# Successfully installed chardet-3.0.4 googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.11.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedShuffleSplit
import re
from sklearn.utils.class_weight import compute_class_weight
import random
# from googletrans import Translator

# %% [markdown]
# data load

# %%
train_원본 = pd.read_excel('/content/drive/MyDrive/프로젝트NLP/train_원본.xlsx')
train_aug = pd.read_excel('/content/drive/MyDrive/프로젝트NLP/train_aug.xlsx')
val = pd.read_excel('/content/drive/MyDrive/프로젝트NLP/val.xlsx')
test = pd.read_excel('/content/drive/MyDrive/프로젝트NLP/test.xlsx')

train_aug = train_aug.rename(columns={'text_aug':'text'})
concat2 = pd.concat([train_원본, train_aug]).reset_index(drop=True)

back1 = pd.read_excel('/content/drive/MyDrive/프로젝트NLP/먼저만개_back.xlsx')
back2  = pd.read_excel('/content/drive/MyDrive/프로젝트NLP/먼저만개2_back.xlsx')
back3 = pd.read_excel('/content/drive/MyDrive/프로젝트NLP/먼저만개3_back.xlsx')
back4 = pd.read_excel('/content/drive/MyDrive/프로젝트NLP/먼저만개4_back.xlsx')

train_back = pd.concat([back1, back2, back3, back4]).reset_index(drop=True)
final = pd.concat([concat2, train_back]).reset_index(drop=True)

# %%
# train_back.to_excel('/content/drive/MyDrive/프로젝트NLP/train_backaug.xlsx', index=False)

# %%
final_shuffled = final.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
final_shuffled
# Out:
#                                                     text    y
# 0      This customer is 53 years old, works as a serv...   no
# 1      This customer is 45 years old, works as admini...   no
# 2      This customer is 33 years old, works as a blue...   no
# 3      This customer is 51 years old, works as a admi...   no
# 4      The customer was 55 years old and worked as an...   no
# ...                                                  ...  ...
# 98415  This customer is 48 years old, works as a admi...   no
# 98416  This customer means 27 years old, works as med...  yes
# 98417  This customer is 46 years old, works as a mana...   no
# 98418  This customer is 37 years old, works as a tech...   no
# 98419  This customer is 39 years old, works as a hous...  yes
#
# [98420 rows x 2 columns]

# %%
# 먼저만개4 = train_원본.loc[30000:,:]
# translator = Translator()

# # 'text' 컬럼의 모든 데이터에 대해 Back Translation 수행
# augmented_texts = []
# labels = []

# for _, row in 먼저만개4.iterrows():
#     text = row['text']
#     label = row['y']
#     try:
#         # Step 1: 영어를 임의의 언어로 번역
#         lang = random.choice(['fr', 'de', 'es', 'ko', 'ja'])  # 프랑스어, 독일어, 스페인어, 한국어, 일본어 중 랜덤 선택
#         translated = translator.translate(text, src='en', dest=lang).text

#         # Step 2: 다시 영어로 번역
#         back_translated = translator.translate(translated, src=lang, dest='en').text

#         # 증강된 텍스트와 원래 라벨을 리스트에 추가
#         augmented_texts.append(back_translated)
#         labels.append(label)
#     except Exception as e:
#         print(f"Translation error for text: {text}, error: {e}")
#         continue

# # 증강된 데이터프레임 생성
# 먼저만개4_back = pd.DataFrame({'text': augmented_texts, 'y': labels})

# 먼저만개4_back.to_excel('/content/drive/MyDrive/프로젝트NLP/먼저만개4_back.xlsx', index=False)
# Out:
# Translation error for text: This customer is 24 years old, works as a blue-collar, and is married. They have completed basic_9y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a thu in apr. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.8%, the consumer price index was 93.075, the consumer confidence index was -47.1, the EURIBOR 3-month rate was 1.41, and the employee count was 5099.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 24 years old, works as a services, and is single. They have completed high_school education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a thu in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.1%, the consumer price index was 93.994, the consumer confidence index was -36.4, the EURIBOR 3-month rate was 4.86, and the employee count was 5191.0., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 45 years old, works as a blue-collar, and is married. They have completed professional_course education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a thu in aug. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.444, the consumer confidence index was -36.1, the EURIBOR 3-month rate was 4.968, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 32 years old, works as a technician, and is single. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a tue in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.8%, the consumer price index was 92.893, the consumer confidence index was -46.2, the EURIBOR 3-month rate was 1.291, and the employee count was 5099.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 38 years old, works as a admin, and is married. They have completed high_school education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a fri in jun. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 94.465, the consumer confidence index was -41.8, the EURIBOR 3-month rate was 4.959, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 45 years old, works as a blue-collar, and is divorced. They have completed basic_9y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a mon in jul. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.918, the consumer confidence index was -42.7, the EURIBOR 3-month rate was 4.962, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 29 years old, works as a blue-collar, and is single. They have completed basic_9y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a tue in jul. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.918, the consumer confidence index was -42.7, the EURIBOR 3-month rate was 4.961, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 41 years old, works as a blue-collar, and is divorced. They have completed basic_4y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a fri in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.1%, the consumer price index was 93.994, the consumer confidence index was -36.4, the EURIBOR 3-month rate was 4.855, and the employee count was 5191.0., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 57 years old, works as a blue-collar, and is married. They have completed basic_9y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a mon in aug. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.444, the consumer confidence index was -36.1, the EURIBOR 3-month rate was 4.965, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 51 years old, works as a blue-collar, and is married. They have completed basic_4y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a tue in nov. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -0.1%, the consumer price index was 93.2, the consumer confidence index was -42.0, the EURIBOR 3-month rate was 4.1530000000000005, and the employee count was 5195.8., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 50 years old, works as a entrepreneur, and is married. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a tue in nov. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -0.1%, the consumer price index was 93.2, the consumer confidence index was -42.0, the EURIBOR 3-month rate was 4.7, and the employee count was 5195.8., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 31 years old, works as a services, and is single. They have completed high_school education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a thu in jul. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.918, the consumer confidence index was -42.7, the EURIBOR 3-month rate was 4.968, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 46 years old, works as a unemployed, and is married. They have completed basic_6y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a thu in nov. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -0.1%, the consumer price index was 93.2, the consumer confidence index was -42.0, the EURIBOR 3-month rate was 4.0760000000000005, and the employee count was 5195.8., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 42 years old, works as a blue-collar, and is married. They have completed basic_4y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a mon in jul. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.918, the consumer confidence index was -42.7, the EURIBOR 3-month rate was 4.96, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 39 years old, works as a blue-collar, and is divorced. They have completed basic_9y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a wed in jun. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 94.465, the consumer confidence index was -41.8, the EURIBOR 3-month rate was 4.962, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 37 years old, works as a blue-collar, and is divorced. They have completed basic_9y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a thu in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.8%, the consumer price index was 92.893, the consumer confidence index was -46.2, the EURIBOR 3-month rate was 1.266, and the employee count was 5099.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 41 years old, works as a housemaid, and is married. They have completed basic_4y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a thu in jul. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.918, the consumer confidence index was -42.7, the EURIBOR 3-month rate was 4.968, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 51 years old, works as a management, and is married. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a wed in mar. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.8%, the consumer price index was 93.369, the consumer confidence index was -34.8, the EURIBOR 3-month rate was 0.655, and the employee count was 5008.7., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 34 years old, works as a management, and is married. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a thu in jun. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -2.9%, the consumer price index was 92.963, the consumer confidence index was -40.8, the EURIBOR 3-month rate was 1.26, and the employee count was 5076.2., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 37 years old, works as a admin, and is single. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a mon in aug. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.444, the consumer confidence index was -36.1, the EURIBOR 3-month rate was 4.965, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 51 years old, works as a blue-collar, and is married. They have completed high_school education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a fri in nov. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -0.1%, the consumer price index was 93.2, the consumer confidence index was -42.0, the EURIBOR 3-month rate was 4.021, and the employee count was 5195.8., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 38 years old, works as a services, and is single. They have completed high_school education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a wed in apr. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.8%, the consumer price index was 93.075, the consumer confidence index was -47.1, the EURIBOR 3-month rate was 1.445, and the employee count was 5099.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 61 years old, works as a admin, and is married. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a thu in apr. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.8%, the consumer price index was 93.075, the consumer confidence index was -47.1, the EURIBOR 3-month rate was 1.406, and the employee count was 5099.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 32 years old, works as a technician, and is single. They have completed high_school education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a wed in jul. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.918, the consumer confidence index was -42.7, the EURIBOR 3-month rate was 4.963, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 30 years old, works as a services, and is single. They have completed high_school education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a tue in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.1%, the consumer price index was 93.994, the consumer confidence index was -36.4, the EURIBOR 3-month rate was 4.856, and the employee count was 5191.0., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 43 years old, works as a technician, and is single. They have completed professional_course education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a fri in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.1%, the consumer price index was 93.994, the consumer confidence index was -36.4, the EURIBOR 3-month rate was 4.855, and the employee count was 5191.0., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 42 years old, works as a technician, and is single. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a thu in aug. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.444, the consumer confidence index was -36.1, the EURIBOR 3-month rate was 4.964, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 27 years old, works as a admin, and is single. They have completed high_school education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a tue in jul. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.918, the consumer confidence index was -42.7, the EURIBOR 3-month rate was 4.962, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 53 years old, works as a technician, and is married. They have completed professional_course education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a tue in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.1%, the consumer price index was 93.994, the consumer confidence index was -36.4, the EURIBOR 3-month rate was 4.856, and the employee count was 5191.0., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 52 years old, works as a technician, and is single. They have completed professional_course education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a wed in aug. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.444, the consumer confidence index was -36.1, the EURIBOR 3-month rate was 4.967, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 46 years old, works as a management, and is married. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a mon in jul. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.918, the consumer confidence index was -42.7, the EURIBOR 3-month rate was 4.962, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 30 years old, works as a technician, and is single. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a tue in mar. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.8%, the consumer price index was 93.369, the consumer confidence index was -34.8, the EURIBOR 3-month rate was 0.6459999999999999, and the employee count was 5008.7., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 40 years old, works as a blue-collar, and is married. They have completed basic_9y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a thu in apr. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.8%, the consumer price index was 93.075, the consumer confidence index was -47.1, the EURIBOR 3-month rate was 1.483, and the employee count was 5099.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 44 years old, works as a management, and is single. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a fri in nov. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -0.1%, the consumer price index was 93.2, the consumer confidence index was -42.0, the EURIBOR 3-month rate was 4.021, and the employee count was 5195.8., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 38 years old, works as a management, and is divorced. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a fri in apr. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.8%, the consumer price index was 93.075, the consumer confidence index was -47.1, the EURIBOR 3-month rate was 1.405, and the employee count was 5099.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 35 years old, works as a technician, and is single. They have completed professional_course education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a thu in aug. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.444, the consumer confidence index was -36.1, the EURIBOR 3-month rate was 4.963, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 55 years old, works as a entrepreneur, and is married. They have completed professional_course education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a thu in nov. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -0.1%, the consumer price index was 93.2, the consumer confidence index was -42.0, the EURIBOR 3-month rate was 4.0760000000000005, and the employee count was 5195.8., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 30 years old, works as a admin, and is single. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a mon in aug. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.444, the consumer confidence index was -36.1, the EURIBOR 3-month rate was 4.963, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 46 years old, works as a entrepreneur, and is divorced. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a thu in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.1%, the consumer price index was 93.994, the consumer confidence index was -36.4, the EURIBOR 3-month rate was 4.86, and the employee count was 5191.0., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 31 years old, works as a housemaid, and is single. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a mon in nov. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.1%, the consumer price index was 94.767, the consumer confidence index was -50.8, the EURIBOR 3-month rate was 1.039, and the employee count was 4963.6., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 45 years old, works as a entrepreneur, and is married. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a mon in aug. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.444, the consumer confidence index was -36.1, the EURIBOR 3-month rate was 4.965, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 31 years old, works as a blue-collar, and is married. They have completed basic_4y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a fri in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.1%, the consumer price index was 93.994, the consumer confidence index was -36.4, the EURIBOR 3-month rate was 4.855, and the employee count was 5191.0., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 62 years old, works as a technician, and is married. They have completed unknown education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a mon in mar. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.8%, the consumer price index was 93.369, the consumer confidence index was -34.8, the EURIBOR 3-month rate was 0.6459999999999999, and the employee count was 5008.7., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 53 years old, works as a unemployed, and is single. They have completed basic_9y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a fri in nov. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -0.1%, the consumer price index was 93.2, the consumer confidence index was -42.0, the EURIBOR 3-month rate was 4.021, and the employee count was 5195.8., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 51 years old, works as a blue-collar, and is single. They have completed basic_4y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a wed in jul. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.918, the consumer confidence index was -42.7, the EURIBOR 3-month rate was 4.963, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 48 years old, works as a blue-collar, and is married. They have completed basic_9y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a thu in aug. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.444, the consumer confidence index was -36.1, the EURIBOR 3-month rate was 4.963, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 56 years old, works as a services, and is married. They have completed basic_9y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a mon in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.1%, the consumer price index was 93.994, the consumer confidence index was -36.4, the EURIBOR 3-month rate was 4.857, and the employee count was 5191.0., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 29 years old, works as a technician, and is single. They have completed basic_9y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a wed in jul. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.7%, the consumer price index was 94.215, the consumer confidence index was -40.3, the EURIBOR 3-month rate was 0.84, and the employee count was 4991.6., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 34 years old, works as a housemaid, and is married. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a thu in aug. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -2.9%, the consumer price index was 92.201, the consumer confidence index was -31.4, the EURIBOR 3-month rate was 0.873, and the employee count was 5076.2., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 47 years old, works as a technician, and is married. They have completed high_school education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a mon in aug. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.444, the consumer confidence index was -36.1, the EURIBOR 3-month rate was 4.965, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 38 years old, works as a admin, and is divorced. They have completed high_school education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a thu in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.1%, the consumer price index was 93.994, the consumer confidence index was -36.4, the EURIBOR 3-month rate was 4.86, and the employee count was 5191.0., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 49 years old, works as a services, and is married. They have completed high_school education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a tue in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.1%, the consumer price index was 93.994, the consumer confidence index was -36.4, the EURIBOR 3-month rate was 4.856, and the employee count was 5191.0., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 38 years old, works as a services, and is married. They have completed high_school education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a thu in jul. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.918, the consumer confidence index was -42.7, the EURIBOR 3-month rate was 4.968, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 51 years old, works as a technician, and is married. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a thu in apr. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.8%, the consumer price index was 93.075, the consumer confidence index was -47.1, the EURIBOR 3-month rate was 1.365, and the employee count was 5099.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 22 years old, works as a admin, and is single. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a mon in sep. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.1%, the consumer price index was 94.199, the consumer confidence index was -37.5, the EURIBOR 3-month rate was 0.882, and the employee count was 4963.6., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 33 years old, works as a admin, and is single. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a tue in jun. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -2.9%, the consumer price index was 92.963, the consumer confidence index was -40.8, the EURIBOR 3-month rate was 1.262, and the employee count was 5076.2., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 48 years old, works as a admin, and is married. They have completed basic_9y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a fri in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.1%, the consumer price index was 93.994, the consumer confidence index was -36.4, the EURIBOR 3-month rate was 4.855, and the employee count was 5191.0., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 44 years old, works as a blue-collar, and is married. They have completed basic_9y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a wed in aug. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.444, the consumer confidence index was -36.1, the EURIBOR 3-month rate was 4.964, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 33 years old, works as a admin, and is divorced. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a mon in aug. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.444, the consumer confidence index was -36.1, the EURIBOR 3-month rate was 4.97, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 32 years old, works as a blue-collar, and is married. They have completed basic_6y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a mon in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.8%, the consumer price index was 92.893, the consumer confidence index was -46.2, the EURIBOR 3-month rate was 1.2990000000000002, and the employee count was 5099.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 45 years old, works as a admin, and is married. They have completed high_school education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a wed in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.1%, the consumer price index was 93.994, the consumer confidence index was -36.4, the EURIBOR 3-month rate was 4.859, and the employee count was 5191.0., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 44 years old, works as a admin, and is divorced. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a mon in aug. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.444, the consumer confidence index was -36.1, the EURIBOR 3-month rate was 4.963, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 31 years old, works as a blue-collar, and is married. They have completed basic_6y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a wed in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.1%, the consumer price index was 93.994, the consumer confidence index was -36.4, the EURIBOR 3-month rate was 4.856, and the employee count was 5191.0., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 42 years old, works as a blue-collar, and is married. They have completed basic_4y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a wed in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.8%, the consumer price index was 92.893, the consumer confidence index was -46.2, the EURIBOR 3-month rate was 1.281, and the employee count was 5099.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 37 years old, works as a admin, and is single. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a fri in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.8%, the consumer price index was 92.893, the consumer confidence index was -46.2, the EURIBOR 3-month rate was 1.3130000000000002, and the employee count was 5099.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 48 years old, works as a technician, and is married. They have completed high_school education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a tue in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.1%, the consumer price index was 93.994, the consumer confidence index was -36.4, the EURIBOR 3-month rate was 4.856, and the employee count was 5191.0., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 29 years old, works as a technician, and is single. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a mon in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.1%, the consumer price index was 93.994, the consumer confidence index was -36.4, the EURIBOR 3-month rate was 4.8580000000000005, and the employee count was 5191.0., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 27 years old, works as a admin, and is single. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a fri in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.8%, the consumer price index was 92.893, the consumer confidence index was -46.2, the EURIBOR 3-month rate was 1.259, and the employee count was 5099.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 31 years old, works as a admin, and is single. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a mon in aug. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.7%, the consumer price index was 94.027, the consumer confidence index was -38.3, the EURIBOR 3-month rate was 0.8959999999999999, and the employee count was 4991.6., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 42 years old, works as a management, and is married. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a wed in sep. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.1%, the consumer price index was 94.199, the consumer confidence index was -37.5, the EURIBOR 3-month rate was 0.8859999999999999, and the employee count was 4963.6., error: 'Translator' object has no attribute 'raise_Exception'
# ...
# Translation error for text: This customer is 30 years old, works as a technician, and is single. They have completed high_school education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a tue in jul. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.918, the consumer confidence index was -42.7, the EURIBOR 3-month rate was 4.962, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 53 years old, works as a services, and is married. They have completed basic_6y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a thu in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.8%, the consumer price index was 92.893, the consumer confidence index was -46.2, the EURIBOR 3-month rate was 1.266, and the employee count was 5099.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 41 years old, works as a blue-collar, and is married. They have completed basic_9y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a fri in jun. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 94.465, the consumer confidence index was -41.8, the EURIBOR 3-month rate was 4.967, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 31 years old, works as a services, and is married. They have completed basic_9y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a mon in jun. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -2.9%, the consumer price index was 92.963, the consumer confidence index was -40.8, the EURIBOR 3-month rate was 1.266, and the employee count was 5076.2., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 34 years old, works as a technician, and is single. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a wed in aug. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.444, the consumer confidence index was -36.1, the EURIBOR 3-month rate was 4.967, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 32 years old, works as a services, and is single. They have completed high_school education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a mon in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.1%, the consumer price index was 93.994, the consumer confidence index was -36.4, the EURIBOR 3-month rate was 4.857, and the employee count was 5191.0., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 50 years old, works as a management, and is married. They have completed professional_course education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a wed in aug. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.444, the consumer confidence index was -36.1, the EURIBOR 3-month rate was 4.964, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 37 years old, works as a technician, and is single. They have completed high_school education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a mon in jun. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 94.465, the consumer confidence index was -41.8, the EURIBOR 3-month rate was 4.96, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 30 years old, works as a admin, and is single. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a thu in apr. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.8%, the consumer price index was 93.075, the consumer confidence index was -47.1, the EURIBOR 3-month rate was 1.365, and the employee count was 5099.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 35 years old, works as a technician, and is married. They have completed unknown education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a thu in jul. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.918, the consumer confidence index was -42.7, the EURIBOR 3-month rate was 4.963, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 36 years old, works as a admin, and is married. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a fri in jun. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.7%, the consumer price index was 94.055, the consumer confidence index was -39.8, the EURIBOR 3-month rate was 0.748, and the employee count was 4991.6., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 28 years old, works as a management, and is single. They have completed unknown education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a thu in jul. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.918, the consumer confidence index was -42.7, the EURIBOR 3-month rate was 4.966, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 35 years old, works as a entrepreneur, and is single. They have completed basic_9y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a mon in nov. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -0.1%, the consumer price index was 93.2, the consumer confidence index was -42.0, the EURIBOR 3-month rate was 4.191, and the employee count was 5195.8., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 35 years old, works as a admin, and is married. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a wed in nov. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -0.1%, the consumer price index was 93.2, the consumer confidence index was -42.0, the EURIBOR 3-month rate was 4.12, and the employee count was 5195.8., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 30 years old, works as a technician, and is single. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a thu in aug. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.444, the consumer confidence index was -36.1, the EURIBOR 3-month rate was 4.968, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 31 years old, works as a admin, and is married. They have completed high_school education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a tue in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.1%, the consumer price index was 93.994, the consumer confidence index was -36.4, the EURIBOR 3-month rate was 4.856, and the employee count was 5191.0., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 52 years old, works as a management, and is divorced. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a mon in nov. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -0.1%, the consumer price index was 93.2, the consumer confidence index was -42.0, the EURIBOR 3-month rate was 4.191, and the employee count was 5195.8., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 53 years old, works as a retired, and is married. They have completed basic_6y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a thu in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.1%, the consumer price index was 93.994, the consumer confidence index was -36.4, the EURIBOR 3-month rate was 4.855, and the employee count was 5191.0., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 29 years old, works as a blue-collar, and is single. They have completed basic_9y education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a fri in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.1%, the consumer price index was 93.994, the consumer confidence index was -36.4, the EURIBOR 3-month rate was 4.864, and the employee count was 5191.0., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 56 years old, works as a admin, and is married. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a mon in aug. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.444, the consumer confidence index was -36.1, the EURIBOR 3-month rate was 4.97, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 35 years old, works as a entrepreneur, and is married. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by telephone, with the most recent contact occurring on a fri in jun. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 94.465, the consumer confidence index was -41.8, the EURIBOR 3-month rate was 4.959, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 50 years old, works as a services, and is single. They have completed high_school education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a wed in jul. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was 1.4%, the consumer price index was 93.918, the consumer confidence index was -42.7, the EURIBOR 3-month rate was 4.963, and the employee count was 5228.1., error: 'Translator' object has no attribute 'raise_Exception'
# Translation error for text: This customer is 31 years old, works as a technician, and is single. They have completed university_degree education, have no credit issues, and do not have a housing or personal loan. The previous contact was made by cellular, with the most recent contact occurring on a mon in may. The customer has never been contacted before and did not participate in previous marketing campaigns. At that time, the quarterly employment change rate was -1.8%, the consumer price index was 92.893, the consumer confidence index was -46.2, the EURIBOR 3-month rate was 1.2990000000000002, and the employee count was 5099.1., error: 'Translator' object has no attribute 'raise_Exception'

# %% [markdown]
# roberta classification

# %%
import torch
import os
from torch.utils.data import DataLoader, Dataset
from transformers import RobertaTokenizer, RobertaForSequenceClassification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import classification_report, f1_score, matthews_corrcoef
from transformers import DataCollatorForLanguageModeling
from torch.optim import AdamW

# 1. 데이터셋 정의
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, index):
        text = self.texts[index]
        label = self.labels[index]

        if isinstance(text, list):
          text = f" {self.tokenizer.sep_token} ".join(text)

        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            return_token_type_ids=False,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt',
        )

        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor(label, dtype=torch.long)
        }

# %% [markdown]
# 'learning_rate': 0.000003, 'batch_size': 32, 'weight_decay': 0
#
# Best model saved with F1 score: 0.5071
# Train loss 0.5239019664601214 F1 score 0.49255708004449866 MCC 04254117356247446
# Val loss 0.5250794845958089 F1 score 0.5070671378091872 MCC 0.44111638375736484

# %%
## Aug는 내꺼만 사용/ class-weight balanced o / undersampling x

# %%
train_texts = final_shuffled['text']
val_texts = val['text']
train_labels = final_shuffled['y']
val_labels = val['y']

label_mapping = {'yes': 1, 'no': 0}

train_labels = final_shuffled['y'].map(label_mapping)
val_labels = val['y'].map(label_mapping)

# 로버타 토크나이저 로드
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')

# 데이터셋 생성
train_dataset = TextDataset(train_texts, train_labels, tokenizer, max_len=160)
val_dataset = TextDataset(val_texts, val_labels, tokenizer, max_len=160)


# 데이터로더 생성
train_dataloader = DataLoader(train_dataset, batch_size=128, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=128, shuffle = False)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(train_labels), y=train_labels)
class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)

# 3. 모델 정의
model = RobertaForSequenceClassification.from_pretrained('roberta-base', num_labels=2)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# 4. 옵티마이저 및 손실 함수 정의
optimizer = AdamW(model.parameters(), lr=0.000003)

# 가중치를 적용한 손실 함수 정의
loss_fn = torch.nn.CrossEntropyLoss(weight=class_weights)

# 5. 모델 학습
def train_epoch(model, dataloader, optimizer, device, loss_fn):
    model.train()
    losses = []
    y_true = []
    y_preds = []

    for batch in dataloader:
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        logits = outputs.logits

        loss = loss_fn(logits, labels)  # 가중치가 적용된 손실 함수 사용
        _, preds = torch.max(logits, dim=1)
        y_true.extend(labels.cpu().numpy())
        y_preds.extend(preds.cpu().numpy())
        losses.append(loss.item())

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

    avg_f1 = f1_score(y_true, y_preds, average='binary')
    avg_mcc = matthews_corrcoef(y_true, y_preds)  # MCC 추가
    return avg_f1, avg_mcc, np.mean(losses)

# 6. 모델 평가
def eval_model(model, dataloader, device, loss_fn):
    model.eval()
    losses = []
    y_true = []
    y_preds = []
    y_probas = []

    with torch.no_grad():
        for batch in dataloader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            logits = outputs.logits

            loss = loss_fn(logits, labels)  # 가중치가 적용된 손실 함수 사용
            _, preds = torch.max(logits, dim=1)
            y_true.extend(labels.cpu().numpy())
            y_preds.extend(preds.cpu().numpy())
            losses.append(loss.item())

            proba = torch.softmax(logits, dim=1)[:, 1].cpu().numpy()
            y_probas.extend(proba)

    avg_f1 = f1_score(y_true, y_preds, average='binary')
    avg_mcc = matthews_corrcoef(y_true, y_preds)  # MCC 추가
    return avg_f1, avg_mcc, np.mean(losses), y_preds, y_probas


# 모델 저장 경로 설정
best_model_path = "best_model.pth"
best_f1_score = 0.0  # 가장 높은 F1 score를 기록

epochs = 10

for epoch in range(epochs):
    print(f'Epoch {epoch + 1}/{epochs}')
    print('-' * 10)

    train_f1, train_mcc, train_loss = train_epoch(model, train_dataloader, optimizer, device, loss_fn)
    print(f'Train loss {train_loss} F1 score {train_f1} MCC {train_mcc}')

    val_f1, val_mcc, val_loss, val_pred, val_proba = eval_model(model, val_dataloader, device, loss_fn)
    print(f'Val loss {val_loss} F1 score {val_f1} MCC {val_mcc}')

    if val_f1 > best_f1_score:
        best_f1_score = val_f1
        torch.save(model.state_dict(), best_model_path)
        print(f"Best model saved with F1 score: {best_f1_score:.4f}")

print(f"Loading best model with F1 score: {best_f1_score:.4f}")
model.load_state_dict(torch.load(best_model_path))
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/10
# ----------
# Train loss 0.6069396886930974 F1 score 0.32223849689378253 MCC 0.2244375619315046
# Val loss 0.542648353359916 F1 score 0.45668016194331984 MCC 0.384178424690617
# Best model saved with F1 score: 0.4567
# Epoch 2/10
# ----------
# Train loss 0.556464066779815 F1 score 0.43083117630140927 MCC 0.35521253280690446
# Val loss 0.5435070684461882 F1 score 0.4713804713804714 MCC 0.4003448802488652
# Best model saved with F1 score: 0.4714
# Epoch 3/10
# ----------
# Train loss 0.5516065824171347 F1 score 0.4401150627615063 MCC 0.36557139321761156
# Val loss 0.5336637198925018 F1 score 0.483704974271012 MCC 0.4144042765751665
# Best model saved with F1 score: 0.4837
# Epoch 4/10
# ----------
# Train loss 0.5468857531739769 F1 score 0.44750181028240404 MCC 0.37432498907932854
# Val loss 0.5282390009273182 F1 score 0.5070422535211268 MCC 0.44119844790099744
# Best model saved with F1 score: 0.5070
# Epoch 5/10
# ----------
# Train loss 0.5427756603657037 F1 score 0.45939162734665195 MCC 0.3880633758682781
# Val loss 0.5219510766592893 F1 score 0.4909983633387889 MCC 0.42527987302649195
# Epoch 6/10
# ----------
# Train loss 0.5379603334614143 F1 score 0.4649656001603099 MCC 0.3949774904150618
# Val loss 0.5198352991631536 F1 score 0.478017585931255 MCC 0.4108491724342898
# Epoch 7/10
# ----------
# Train loss 0.5364064714921001 F1 score 0.4678567812911281 MCC 0.39796101842211484
# Val loss 0.5236447069681052 F1 score 0.48776508972267535 MCC 0.4215461322799757
# Epoch 8/10
# ----------
# Train loss 0.5326525805752981 F1 score 0.4713255610216322 MCC 0.4022650984305222
# Val loss 0.5315813986640988 F1 score 0.5021570319240725 MCC 0.43613004714497494
# Epoch 9/10
# ----------
# Train loss 0.5316184099923494 F1 score 0.4692176358340866 MCC 0.4000444855684244
# Val loss 0.5208462408997796 F1 score 0.4919966301600674 MCC 0.42501245576867425
# Epoch 10/10
# ----------
# Train loss 0.529074273509384 F1 score 0.47141424272818455 MCC 0.40280058999754564
# Val loss 0.5327689841841207 F1 score 0.5043936731107206 MCC 0.438127875366436
# Loading best model with F1 score: 0.5070
# <ipython-input-14-d1a14c242bab>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_path))
# <All keys matched successfully>

# %%
test_texts = test['text']
test_labels = test['y']

test_labels = test['y'].map(label_mapping)

test_dataset = TextDataset(test_texts, test_labels, tokenizer, max_len=160)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False)


test_f1, test_mcc, test_loss, test_pred, test_proba = eval_model(model, test_dataloader, device, loss_fn)
print(f'test loss {test_loss} F1 score {test_f1} MCC {test_mcc}')
# Out:
# test loss 0.5287362470076634 F1 score 0.503584229390681 MCC 0.43663395473691896

# %%
val_results = pd.DataFrame({
    'true_label': val_labels,  # 실제 레이블
    'predicted_label': val_pred,  # 예측 레이블
    'predicted_proba': val_proba  # 예측 확률
})
val_results.to_csv('/content/drive/MyDrive/프로젝트NLP/model_predictions/roberta_val_predictions2.csv', index=False)

# 테스트 데이터 예측값과 예측 확률을 CSV로 저장
test_results = pd.DataFrame({
    'true_label': test_labels,  # 실제 레이블
    'predicted_label': test_pred,  # 예측 레이블
    'predicted_proba': test_proba  # 예측 확률
})
test_results.to_csv('/content/drive/MyDrive/프로젝트NLP/model_predictions/roberta_test_predictions2.csv', index=False)

print("CSV files for val and test predictions saved!")
# Out:
# CSV files for val and test predictions saved!

# %%
model_path = "/content/drive/MyDrive/프로젝트NLP/학습모델weight/best_model.pth"
class_weights_path = "/content/drive/MyDrive/프로젝트NLP/학습모델weight/class_weights.pth"

torch.save(model.state_dict(), model_path)
torch.save(class_weights, class_weights_path)

# # Google Drive에서 파일 로드
# model.load_state_dict(torch.load("/content/drive/MyDrive/best_model.pth"))
# class_weights = torch.load("/content/drive/MyDrive/class_weights.pth").to(device)
